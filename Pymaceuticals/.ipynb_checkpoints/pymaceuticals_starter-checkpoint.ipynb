# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# 1.  Based on the data, the best drug regimens for this study are Capomulin and Ramicane.  This is based on the information in the box plot that shows these two drugs stayed in the inner bounds of the avg tumor volume.
#
# 2.  Mouse x401 showed drastic reduction in tumor volume on Campomulin but towards the later timepoint the volume seemed to increase.
#
# 3.  There is a direct coorilation between the mouses's weight and the tumor volume.  The scatter plot clearly shows that as the weight of the mouse increses the size of it's tumor does as well.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merged_df = pd.merge(mouse_metadata, study_results, on = "Mouse ID")

# Display the data table for preview
merged_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
len(merged_df["Mouse ID"].unique())
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_df = merged_df[merged_df.duplicated(subset = ["Mouse ID", "Timepoint"])]
duplicate_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
merged_df[merged_df["Mouse ID"]=="g989"]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_data = merged_df.loc[merged_df["Mouse ID"] != "g989"]
clean_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
len(clean_data["Mouse ID"].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
summary_df = clean_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].describe()
summary_df = summary_df[["mean", "std"]]
summary_df["var"] =  clean_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].var()
summary_df["median"] =  clean_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].median()
summary_df["sem"] =  clean_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].sem()
summary_df = summary_df[["mean", "median","var", "std","sem"]]
summary_df
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
summary_agg = clean_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].agg(["mean", "median", "var", "std", "sem"])
summary_agg
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.
regimen_group = clean_data.groupby("Drug Regimen").count()
pandas_bar = regimen_group[["Mouse ID"]]
pandas_bar.plot(kind = "bar", alpha = .50)
plt.ylabel("# of Measurements")
plt.title("Total # Measurements per Regimen")
plt.legend(['Total #'])
plt.show()

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.
x_axis = np.arange(len(regimen_group))
tick_locations = [x *1.7 for x in x_axis]
plt.bar(tick_locations, pandas_bar["Mouse ID"], alpha = .5, align = "center", label = "Total Measurements")
plt.xticks(tick_locations, regimen_group.index, rotation = "vertical")
plt.xlabel("Drug Regimen")
plt.title("Total # Measurements per Regimen")
plt.ylabel("# of Measurements")
plt.legend(loc = "best")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
sex_df = clean_data.drop_duplicates(subset = "Mouse ID").groupby("Sex").count()

colors = ["pink", "blue"]
sex_df.plot(kind = "pie", y = "Mouse ID", title = "Male VS Female Distribution",autopct="%1.1f%%", 
            shadow=True, startangle=140, colors = colors, legend = False).yaxis.set_visible(False)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
males = sex_df.loc["Male", "Mouse ID"]
females = sex_df.loc["Female", "Mouse ID"]

labels = sex_df.index
colors = ["pink", "Blue"]
sizes = [females, males]
plt.pie(sizes,labels=labels, colors = colors,
      autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("Male VS Female Distribution")
# Out:
# Text(0.5, 1.0, 'Male VS Female Distribution')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
copy_clean = pd.DataFrame.copy(clean_data)
final_four = clean_data.set_index("Drug Regimen").loc[["Capomulin","Ramicane", "Infubinol","Ceftamin"]].reset_index()

# Start by getting the last (greatest) timepoint for each mouse
final_four = final_four.groupby("Mouse ID")["Timepoint"].max()
final_four = pd.DataFrame(final_four).reset_index()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
merged = pd.merge(copy_clean, final_four, on = ["Timepoint", "Mouse ID"])
merged
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      k403     Ramicane    Male          21          16         45
# 1      s185    Capomulin  Female           3          17         45
# 2      x401    Capomulin  Female          16          15         45
# 3      m601    Capomulin    Male          22          17         45
# 4      g791     Ramicane    Male          11          16         45
# ..      ...          ...     ...         ...         ...        ...
# 95     x822     Ceftamin    Male           3          29         45
# 96     y163    Infubinol  Female          17          27         45
# 97     y769     Ceftamin  Female           6          27         45
# 98     y865     Ceftamin    Male          23          26         45
# 99     z581    Infubinol  Female          24          25         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 0            22.050126                 1
# 1            23.343598                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Ramicane", "Capomulin", "Ceftamin", "Infubinol"]

# Create empty list to fill with tumor vol data (for plotting)
t_vol = {}

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = merged["Tumor Volume (mm3)"].quantile([.25,.50,.75])
lowerq = quartiles[.25]
upperq = quartiles[.75]
IQR = upperq - lowerq

print(f"Lower quartile: {lowerq}.")
print(f"Upper quartile: {upperq}.")
print(f"Interquartile: {IQR}.")
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
for treatment in treatments:
    for index, row in merged.iterrows():
        if row["Drug Regimen"] == treatment:
            t_vol.setdefault(treatment, []).append(row["Tumor Volume (mm3)"])
frame = pd.DataFrame(t_vol)    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
lower_bound = lowerq - (1.5*IQR)
upper_bound = upperq + (1.5*IQR)

print(f"Lower: {lower_bound}")
print(f"Upper: {upper_bound}")
# Out:
# Lower quartile: 37.187743802499995.
# Upper quartile: 59.930261755000004.
# Interquartile: 22.74251795250001.
# Lower: 3.0739668737499812
# Upper: 94.04403868375002

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
plt.boxplot([frame["Ramicane"], frame["Capomulin"], frame["Ceftamin"], frame["Infubinol"]], labels = treatments, sym = "b")
plt.title("Final 4 Drugs")
# Out:
# Text(0.5, 1.0, 'Final 4 Drugs')

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
mouse = clean_data.loc[clean_data["Drug Regimen"] == "Capomulin"].loc[clean_data["Mouse ID"] == "x401"]

mouse_x_axis = mouse["Timepoint"]
mouse_y_axis = mouse["Tumor Volume (mm3)"]
plt.plot(mouse_x_axis, mouse_y_axis)
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume")
plt.title("Mouse x401 Tumor over time")
lx_axis
# Out:
# 20     0
# 21     5
# 22    10
# 23    15
# 24    20
# 25    25
# 26    30
# 27    35
# 28    40
# 29    45
# Name: Timepoint, dtype: int64

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
cap_weight = clean_data.loc[clean_data["Drug Regimen"] == "Capomulin"].groupby("Mouse ID").mean()
cap_x_axis = cap_weight["Weight (g)"]
cap_y_axis = cap_weight["Tumor Volume (mm3)"]

#Code from below cells for regression line
correlation = st.pearsonr(cap_x_axis, cap_y_axis)
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(cap_x_axis, cap_y_axis)
regression = cap_x_axis * slope + intercept

plt.scatter(cap_x_axis,cap_y_axis)
plt.title("Capomulin Tumor vol. & Weight")
plt.xlabel("Weight")
plt.ylabel("Tumor Volume")
plt.plot(cap_x_axis,regression, "r-")

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(cap_x_axis, cap_y_axis)
regress_values = cap_x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = 0.95x +21.55
